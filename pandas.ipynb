# %%
import pandas as pd
import numpy as np

# %%
dates = pd.date_range('20190101','20200101',6)
dates
# Out:
# DatetimeIndex(['2019-01-01', '2019-03-15', '2019-05-27', '2019-08-08',
#                '2019-10-20', '2020-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
airports = pd.read_csv("data.csv", header=None, dtype=str)
airports.columns = ["id", "name", "city", "country", "code", "icao", "latitude", "longitude", "altitude", "offset", "dst", "timezone"]
# Read in the airlines data.airlines = pandas.read_csv("airlines.csv", header=None, dtype=str)
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]
# Read in the routes data.routes = pandas.read_csv("routes.csv", header=None, dtype=str)
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-a6558d6ffd28> in <module>()
# ----> 1 airports = pd.read_csv("data.csv", header=None, dtype=str)
#       2 airports.columns = ["id", "name", "city", "country", "code", "icao", "latitude", "longitude", "altitude", "offset", "dst", "timezone"]
#       3 # Read in the airlines data.airlines = pandas.read_csv("airlines.csv", header=None, dtype=str)
#       4 airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]
#       5 # Read in the routes data.routes = pandas.read_csv("routes.csv", header=None, dtype=str)
#
# ...
